# %% [markdown]
# # Classification modeling
# ---

# %% [markdown]
# # TODO:
# - interpret AUC curves
# - can you add CUTI index to the plots of misclassified data? curious about whether misclassifications are concentrated around CUTI values near 0.
# - question whether this notebook is too long.... I could put the log reg models and decision tree models into their own notebooks but it might make model comparison more annoying
#
# ---

# %% [markdown]
# For my baseline model, I need to ask myself what I'm actually trying to do and whether my audience cares more about accuracy or interpretation. In academic settings and Earth sciences, I prefer to prioritize interpretation since I'm working with real-world concepts and I'd like to be able to use these methods to learn about the oceanographic processes at play here. For this reason, I'll be using scikit-learn's Logistic Regression model, a straightforward classification model that prioritizes interpretability over accuracy. There are several assumptions we make about our data when we use this model, including assuming that our independent variables are independent *of each other*.
#
# However, I know this isn't the case in my data and the variables are strongly correlated with each other. Out of curiosity, I'm going to make a model with each feature individually as one way to avoid the multicollinearity, and then use polynomial features to engineer some interaction features and utilize regularization techniques to reduce the effect of multicollinearity.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import random

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, plot_confusion_matrix, classification_report, plot_roc_curve
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text

random.seed(42)

# %% [markdown]
# ---
# ### Load the data

# %%
df = pd.read_csv('../../coastal_upwelling_output/clean_dataframe.csv')

# %%
df
# Out:
#                        time      density  practical_salinity  \
# 0       2017-01-01 00:00:00  1027.258767           33.916755
# 1       2017-01-01 00:01:00  1027.260164           33.917475
# 2       2017-01-01 00:02:00  1027.258920           33.917249
# 3       2017-01-01 00:03:00  1027.258097           33.916964
# 4       2017-01-01 00:04:00  1027.258173           33.917076
# ...                     ...          ...                 ...
# 329194  2017-09-15 23:55:00  1027.366397           33.960043
# 329195  2017-09-15 23:56:00  1027.366555           33.960125
# 329196  2017-09-15 23:57:00  1027.365319           33.959667
# 329197  2017-09-15 23:58:00  1027.364325           33.959192
# 329198  2017-09-15 23:59:00  1027.361044           33.957907
#
#         seawater_temperature  sea_surface_temperature   CUTI  upwelling  \
# 0                   7.766451                   11.273  1.731          1
# 1                   7.760876                   11.268  1.731          1
# 2                   7.767207                   11.267  1.731          1
# 3                   7.771317                   11.267  1.731          1
# 4                   7.771017                   11.278  1.731          1
# ...                      ...                      ...    ...        ...
# 329194              7.866675                   15.198 -0.194          0
# 329195              7.866182                   15.171 -0.194          0
# 329196              7.872284                   15.158 -0.194          0
# 329197              7.876495                   15.199 -0.194          0
# 329198              7.891755                   15.195 -0.194          0
#
#         upwelling_multi
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ...                 ...
# 329194                0
# 329195                0
# 329196                0
# 329197                0
# 329198                0
#
# [329199 rows x 8 columns]

# %% [markdown]
# This dataframe is over 300,000 observations, which I'm hesitant to pass to a model right away. I'm going to resample down to a small size at first, and then add data back in once the workflow is established.

# %%
df['time'] = pd.to_datetime(df['time'])

# %%
df_resampled = df.resample('20T', on='time').mean().dropna(how='all').reset_index().drop(columns=['CUTI', 'density'])
print(df_resampled.shape)
# Out:
# (17714, 6)

# %%
fig, (ax2, ax1) = plt.subplots(2,1, sharex=True, figsize = (24, 12)) 
ax1.scatter(x=df_resampled['time'], y=df_resampled['seawater_temperature'], c='g', s=1)
ax1.set_ylabel('Seawater Temperature at 200 meters', size=24)
ax1.set_title('Resampled Platform Data', size=24)

ax2.scatter(x=df_resampled['time'], y=df_resampled['sea_surface_temperature'], c='b', s=1)
ax2.set_xlabel('Time', size=24)
ax2.set_ylabel('Sea Surface Temperature', size=24)
ax2.set_title('Resampled METBK Data', size=24)

plt.xticks(rotation=35);
plt.tight_layout()

# %%
df_resampled
# Out:
#                      time  practical_salinity  seawater_temperature  \
# 0     2017-01-01 00:00:00           33.917802              7.768099
# 1     2017-01-01 00:20:00           33.923736              7.695256
# 2     2017-01-01 00:40:00           33.925383              7.688413
# 3     2017-01-01 01:00:00           33.926747              7.698557
# 4     2017-01-01 01:20:00           33.916462              7.764130
# ...                   ...                 ...                   ...
# 17709 2017-09-15 22:20:00           33.948736              8.005974
# 17710 2017-09-15 22:40:00           33.946218              8.028650
# 17711 2017-09-15 23:00:00           33.953680              7.949766
# 17712 2017-09-15 23:20:00           33.942572              8.052701
# 17713 2017-09-15 23:40:00           33.953536              7.939834
#
#        sea_surface_temperature  upwelling  upwelling_multi
# 0                     11.27030        1.0              1.0
# 1                     11.26795        1.0              1.0
# 2                     11.26675        1.0              1.0
# 3                     11.26465        1.0              1.0
# 4                     11.26475        1.0              1.0
# ...                        ...        ...              ...
# 17709                 15.24465        0.0              0.0
# 17710                 15.25365        0.0              0.0
# 17711                 15.22895        0.0              0.0
# 17712                 15.17020        0.0              0.0
# 17713                 15.18360        0.0              0.0
#
# [17714 rows x 6 columns]

# %% [markdown]
# ---
# ### Checking feature correlation
#
# One of the big assumptions we make when building logistic regression models is that our independent features are independent of each other. We can print out a heatmap to check whether our features are correlated to each other or not.

# %%
plt.figure(figsize=(8,8))

corr = df_resampled.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))

sns.heatmap(df_resampled.corr(), annot=True, vmin=-1, vmax=1, mask=mask);

# %% [markdown]
# Yup, looks like our features are correlated with each other! We can also tell from this heatmap that seawater temperature collected by the 200 meter platform is most strongly correlated to upwelling of all our features. I'll build a logistic regression model without addressing the multicollinearity first, and then attempt to improve it by using PolynomialFeatures and ridge and lasso penalties.

# %%
sns.pairplot(df_resampled, corner=True, hue='upwelling');

# %% [markdown]
# ---
# ## Logistic regression classifiers
#
# ### Using only one feature
#
# This sections is on building a model with only seawater temperature from the 200 meter platform as the prediction.

# %%
X = df_resampled['seawater_temperature']
y = df_resampled['upwelling']

y.value_counts(normalize=True)
# Out:
# 1.0    0.61951
# 0.0    0.38049
# Name: upwelling, dtype: float64

# %% [markdown]
# If we created a null model that labeled all predictions as the majority class, we'd be correct about 61.96% of the time! This is the accuracy I'm hoping to beat with logistic regression or decision tree models.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# %% [markdown]
# Create a pipeline with StandardScaler and LogisticRegression

# %%
pipe = Pipeline([
    ('sc', StandardScaler()),
    ('logreg', LogisticRegression())
])

# %%
pipe.fit(X_train.values.reshape(-1, 1), y_train)
# Out:
# Pipeline(steps=[('sc', StandardScaler()), ('logreg', LogisticRegression())])

# %%
print(f'Train accuracy: {pipe.score(X_train.values.reshape(-1, 1), y_train)}')
print(f'Test accuracy: {pipe.score(X_test.values.reshape(-1, 1), y_test)}')
# Out:
# Train accuracy: 0.689499435453519
# Test accuracy: 0.6884172499435538

# %%
print(cross_val_score(pipe, X_train.values.reshape(-1, 1), y_train).mean())
print(cross_val_score(pipe, X_test.values.reshape(-1, 1), y_test).mean())
# Out:
# 0.689951072638314
# 0.6884159110328907

# %%
logreg = pipe.named_steps['logreg']
print(f'LogReg Intercept: {logreg.intercept_}')
print(f'LogReg Coef: {logreg.coef_}')
# Out:
# LogReg Intercept: [0.56096136]
# LogReg Coef: [[-0.89346893]]

# %% [markdown]
# This model performs better than our baseline, woohoo! But maybe we can do better with polynomial features.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))

plot_confusion_matrix(pipe, X_train.values.reshape(-1, 1), y_train, ax=ax1)
ax1.set_title('Confusion Matrix: Train Data')

plot_confusion_matrix(pipe, X_test.values.reshape(-1, 1), y_test, ax=ax2)
ax2.set_title('Confusion Matrix: Test Data');

# %%
test_preds = pipe.predict(X_test.values.reshape(-1, 1))
print(classification_report(y_test, test_preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.44      0.52      1685
#          1.0       0.71      0.84      0.77      2744
#
#     accuracy                           0.69      4429
#    macro avg       0.67      0.64      0.64      4429
# weighted avg       0.68      0.69      0.67      4429

# %%
# ROC curve
plot_roc_curve(logreg, X_test.values.reshape(-1, 1), y_test)

# add worst case scenario line
plt.plot([0,1],[0,1], label='baseline', linestyle='--')

# add a legend
plt.legend();
# want AUC (area under curve) to be as close to 1 as possible

# %% [markdown]
# ---
# ### Using PolynomialFeatures
#
# Now let's add those features back in and use feature interactions combined with regularization to try upping the accuracy while accounting for the multicollinearity.

# %% [markdown]
# An easy way to get a variety of feature interactions is using sklearn's PolynomialFeatures function. There are four features in this model, so I'll set the degree to 4 so that there will be an engineered feature that includes all 4 of the original features.

# %%
X = df_resampled.drop(columns=['upwelling', 'upwelling_multi', 'time'])
y = df_resampled['upwelling']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# %%
pipe = Pipeline([
    ('poly', PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)),
    ('sc', StandardScaler()),
    ('logreg', LogisticRegression(max_iter=1000, solver='liblinear'))
])

pipe_params = {
    'logreg__penalty':['l1', 'l2'],
    'logreg__C': np.linspace(0.001, 1, 10)
}

gs_lr = GridSearchCV(pipe, pipe_params, cv=5, verbose=1, return_train_score=True)

gs_lr.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('poly',
#                                         PolynomialFeatures(include_bias=False)),
#                                        ('sc', StandardScaler()),
#                                        ('logreg',
#                                         LogisticRegression(max_iter=1000,
#                                                            solver='liblinear'))]),
#              param_grid={'logreg__C': array([0.001, 0.112, 0.223, 0.334, 0.445, 0.556, 0.667, 0.778, 0.889,
#        1.   ]),
#                          'logreg__penalty': ['l1', 'l2']},
#              return_train_score=True, verbose=1)

# %%
print(f'Best parameters: {gs_lr.best_params_}')
print(f'Best score: {gs_lr.best_score_}')
# Out:
# Best parameters: {'logreg__C': 1.0, 'logreg__penalty': 'l1'}
# Best score: 0.7457282649604818

# %% [markdown]
# Now that we have the best parameters, we can create a logistic regression model with these parameters and see what the coefficients are for our poly features.

# %%
print(gs_lr.cv_results_['mean_train_score'].mean())
print(gs_lr.cv_results_['mean_test_score'].mean())
# Out:
# 0.7405071509220926
# 0.7402709823108771

# %%
print(f'Train accuracy: {gs_lr.score(X_train, y_train)}')
print(f'Test accuracy: {gs_lr.score(X_test, y_test)}')
# Out:
# Train accuracy: 0.7464057207376741
# Test accuracy: 0.7534432151727252

# %% [markdown]
# Question to self: do the coefficients need to be exponentiated to get their actual values, since the logistic regression model uses the logit function to transform the data?

# %%
gs_lr.predict(X_train)
# Out:
# array([1., 0., 1., ..., 0., 0., 1.])

# %%
gs_lr.best_estimator_['logreg'].coef_
# Out:
# array([[  0.        ,  -7.21996137,  -0.04883273,   0.23276715,
#         -10.01624855,   0.        ,  15.06652422,   3.52540692,
#          -4.09042658]])

# %%
poly_features = gs_lr.estimator.named_steps['poly'].fit(X_train).get_feature_names(X.columns)
coefs = gs_lr.best_estimator_['logreg'].coef_[0]

# %%
sorted(list(zip(poly_features, coefs)), key=lambda x: x[1])[:10]
# Out:
# [('practical_salinity seawater_temperature', -10.016248553929849),
#  ('seawater_temperature', -7.219961366984709),
#  ('sea_surface_temperature^2', -4.0904265826268),
#  ('sea_surface_temperature', -0.04883273292087043),
#  ('practical_salinity', 0.0),
#  ('practical_salinity sea_surface_temperature', 0.0),
#  ('practical_salinity^2', 0.23276715499848438),
#  ('seawater_temperature sea_surface_temperature', 3.5254069232415497),
#  ('seawater_temperature^2', 15.066524220615541)]

# %%
sorted(list(zip(poly_features, coefs)), key=lambda x: x[1])[-10:]
# Out:
# [('practical_salinity seawater_temperature', -10.016248553929849),
#  ('seawater_temperature', -7.219961366984709),
#  ('sea_surface_temperature^2', -4.0904265826268),
#  ('sea_surface_temperature', -0.04883273292087043),
#  ('practical_salinity', 0.0),
#  ('practical_salinity sea_surface_temperature', 0.0),
#  ('practical_salinity^2', 0.23276715499848438),
#  ('seawater_temperature sea_surface_temperature', 3.5254069232415497),
#  ('seawater_temperature^2', 15.066524220615541)]

# %%
gs_lr_train_preds = gs_lr.predict(X_train)
gs_lr_test_preds = gs_lr.predict(X_test)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))

cm = confusion_matrix(y_train, gs_lr_train_preds)
ConfusionMatrixDisplay(cm).plot(ax=ax1)
ax1.set_title('Confusion Matrix: Train Data')

cm = confusion_matrix(y_test, gs_lr_test_preds)
ConfusionMatrixDisplay(cm).plot(ax=ax2)
ax2.set_title('Confusion Matrix: Test Data');

# %% [markdown]
# Looks like our false negatives outnumber our false positives

# %%
print(classification_report(y_test, gs_lr_test_preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.70      0.68      1685
#          1.0       0.81      0.79      0.80      2744
#
#     accuracy                           0.75      4429
#    macro avg       0.74      0.74      0.74      4429
# weighted avg       0.76      0.75      0.75      4429

# %%
# ROC curve
plot_roc_curve(gs_lr, X_test, y_test)

# add worst case scenario line
plt.plot([0,1],[0,1], label='baseline', linestyle='--')

# add a legend
plt.legend();
# want AUC (area under curve) to be as close to 1 as possible

# %% [markdown]
# #### Explore misclassified data

# %%
# Get indices of misclassified data source: https://stackoverflow.com/questions/25551977/retrieve-misclassified-documents-using-scikitlearn
misclass_ind_lr = np.where(y_test != gs_lr_test_preds)
misclass_ind_lr
# Out:
# (array([   2,    8,   11, ..., 4425, 4426, 4427], dtype=int64),)

# %%
X_test_times = df_resampled.iloc[X_test.index]['time']

# %%
X_test_times.iloc[misclass_ind_lr]
# Out:
# 7832    2017-04-22 22:00:00
# 238     2017-01-04 07:20:00
# 1022    2017-01-16 11:00:00
# 546     2017-01-08 14:00:00
# 17165   2017-09-08 09:00:00
#                 ...
# 9663    2017-05-19 14:20:00
# 4956    2017-03-13 23:20:00
# 314     2017-01-05 08:40:00
# 307     2017-01-05 06:20:00
# 7074    2017-04-12 09:20:00
# Name: time, Length: 1092, dtype: datetime64[ns]

# %%
pd.DataFrame(X_test_times.iloc[misclass_ind_lr]).reset_index(drop=True)
# Out:
#                     time
# 0    2017-04-22 22:00:00
# 1    2017-01-04 07:20:00
# 2    2017-01-16 11:00:00
# 3    2017-01-08 14:00:00
# 4    2017-09-08 09:00:00
# ...                  ...
# 1087 2017-05-19 14:20:00
# 1088 2017-03-13 23:20:00
# 1089 2017-01-05 08:40:00
# 1090 2017-01-05 06:20:00
# 1091 2017-04-12 09:20:00
#
# [1092 rows x 1 columns]

# %%
frames_lr = [pd.DataFrame(X_test_times.iloc[misclass_ind_lr]), X_test.iloc[misclass_ind_lr], pd.DataFrame(y_test.iloc[misclass_ind_lr])]
misclass_df_lr = pd.concat(frames_lr, axis=1)

# %%
misclass_df_lr
# Out:
#                      time  practical_salinity  seawater_temperature  \
# 7832  2017-04-22 22:00:00           33.872223              8.268149
# 238   2017-01-04 07:20:00           33.904936              7.847660
# 1022  2017-01-16 11:00:00           33.895588              8.239252
# 546   2017-01-08 14:00:00           33.924423              7.714611
# 17165 2017-09-08 09:00:00           33.987337              7.844016
# ...                   ...                 ...                   ...
# 9663  2017-05-19 14:20:00           33.976587              7.240744
# 4956  2017-03-13 23:20:00           33.918348              8.098221
# 314   2017-01-05 08:40:00           33.895039              7.927354
# 307   2017-01-05 06:20:00           33.897029              7.920439
# 7074  2017-04-12 09:20:00           33.921680              7.779041
#
#        sea_surface_temperature  upwelling
# 7832                 10.734294        1.0
# 238                  10.968450        1.0
# 1022                 10.237200        1.0
# 546                  10.868400        0.0
# 17165                15.461583        0.0
# ...                        ...        ...
# 9663                 12.525300        0.0
# 4956                 10.649550        1.0
# 314                  10.842200        1.0
# 307                  10.870000        1.0
# 7074                 10.378147        1.0
#
# [1092 rows x 5 columns]

# %%
sns.pairplot(misclass_df_lr, corner=True, hue='upwelling');

# %%
fig, (ax2, ax1) = plt.subplots(2,1, sharex=True, figsize = (24, 12)) 
ax1.scatter(x=df_resampled['time'], y=df_resampled['seawater_temperature'], c='g', s=1)
ax1.set_ylabel('Seawater Temperature at 200 meters', size=24)
ax1.set_title('Misclassified Platform Data', size=24)

ax1.scatter(x=misclass_df_lr['time'], y=misclass_df_lr['seawater_temperature'], c='r', s=1)

ax2.scatter(x=df_resampled['time'], y=df_resampled['sea_surface_temperature'], c='b', s=1)
ax2.set_xlabel('Time', size=24)
ax2.set_ylabel('Sea Surface Temperature', size=24)
ax2.set_title('Resampled METBK Data', size=24)

ax2.scatter(x=misclass_df_lr['time'], y=misclass_df_lr['sea_surface_temperature'], c='r', s=1)



plt.xticks(rotation=35);
plt.tight_layout()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,8))

corr = misclass_df_lr.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(misclass_df_lr.corr(), annot=True, vmin=-1, vmax=1, mask=mask, ax=ax1)

corr = df_resampled.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(df_resampled.corr(), annot=True, vmin=-1, vmax=1, mask=mask, ax=ax2);

# %% [markdown]
# ---
# ### Decision tree classifiers
# Decision trees come in a lot of different shapes, so it'd be best to use GridSearchCV to find the best parameters for a tree for upwelling classification.

# %%
X = df_resampled.drop(columns=['time', 'upwelling'])
y = df_resampled['upwelling']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# %%
param_grid = {
    'max_depth': [5, 7, 9],
    'min_samples_split': [5, 10, 15, 20],
    'min_samples_leaf': [2, 3, 4, 5, 6],
    'ccp_alpha': [0, 0.01, 0.1, 1, 10]
}

gs_dt = GridSearchCV(estimator=DecisionTreeClassifier(),
                 param_grid=param_grid,
                 verbose=1,
                 cv=5)

# %time gs_dt.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# Wall time: 33.6 s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'ccp_alpha': [0, 0.01, 0.1, 1, 10],
#                          'max_depth': [5, 7, 9],
#                          'min_samples_leaf': [2, 3, 4, 5, 6],
#                          'min_samples_split': [5, 10, 15, 20]},
#              verbose=1)

# %%
gs_dt.best_estimator_
# Out:
# DecisionTreeClassifier(ccp_alpha=0, max_depth=9, min_samples_leaf=5,
#                        min_samples_split=20)

# %%
print(f'Score on training set: {gs_dt.score(X_train, y_train)}')
print(f'Score on testing set: {gs_dt.score(X_test, y_test)}')
# Out:
# Score on training set: 0.8188934888972526
# Score on testing set: 0.7940844434409573

# %%
gs_dt_train_preds = gs_dt.predict(X_train)
gs_dt_test_preds = gs_dt.predict(X_test)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))

cm = confusion_matrix(y_train, gs_dt_train_preds)
ConfusionMatrixDisplay(cm).plot(ax=ax1)
ax1.set_title('Confusion Matrix: Train Data')

cm = confusion_matrix(y_test, gs_dt_test_preds)
ConfusionMatrixDisplay(cm).plot(ax=ax2)
ax2.set_title('Confusion Matrix: Test Data');

# %%
print(gs_dt.best_estimator_.feature_importances_)
list(X_train.columns)
# Out:
# [0.1392712  0.14221166 0.71851714]
# ['practical_salinity', 'seawater_temperature', 'sea_surface_temperature']

# %% [markdown]
# We saw that `seawater_temperature` was the most strongly correlated feature to upwelling, but `sea_surface_temperature` ended up having the greatest feature importance. I want to trust the model on this, but I'm wondering why this happened.

# %%
# Establish size of figure.
plt.figure(figsize = (50, 30))

# Plot our tree.
plot_tree(gs_dt.best_estimator_,
          feature_names = X_train.columns,
          class_names = ['Not upwelling', 'Upwelling'],
          filled = True);

# %%
print(export_text(gs_dt.best_estimator_,
                  list(X_train.columns)));
# Out:
# |--- sea_surface_temperature <= 11.01
# |   |--- seawater_temperature <= 8.79
# |   |   |--- sea_surface_temperature <= 10.83
# |   |   |   |--- sea_surface_temperature <= 10.52
# |   |   |   |   |--- practical_salinity <= 33.84
# |   |   |   |   |   |--- sea_surface_temperature <= 10.38
# |   |   |   |   |   |   |--- practical_salinity <= 33.79
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- practical_salinity >  33.79
# |   |   |   |   |   |   |   |--- seawater_temperature <= 8.33
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  8.33
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 8.58
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  8.58
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- sea_surface_temperature >  10.38
# |   |   |   |   |   |   |--- sea_surface_temperature <= 10.44
# |   |   |   |   |   |   |   |--- seawater_temperature <= 8.51
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.83
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.83
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  8.51
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.81
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.81
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sea_surface_temperature >  10.44
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 10.50
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 8.61
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  8.61
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  10.50
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.84
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.84
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- practical_salinity >  33.84
# |   |   |   |   |   |--- sea_surface_temperature <= 10.19
# |   |   |   |   |   |   |--- sea_surface_temperature <= 10.12
# |   |   |   |   |   |   |   |--- seawater_temperature <= 8.10
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 10.06
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  10.06
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  8.10
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.86
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.86
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sea_surface_temperature >  10.12
# |   |   |   |   |   |   |   |--- practical_salinity <= 33.94
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 10.17
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  10.17
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- practical_salinity >  33.94
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- sea_surface_temperature >  10.19
# |   |   |   |   |   |   |--- sea_surface_temperature <= 10.51
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.92
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 10.43
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  10.43
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.92
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 10.48
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  10.48
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sea_surface_temperature >  10.51
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.76
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.76
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.94
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.94
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- sea_surface_temperature >  10.52
# |   |   |   |   |--- sea_surface_temperature <= 10.61
# |   |   |   |   |   |--- seawater_temperature <= 8.00
# |   |   |   |   |   |   |--- sea_surface_temperature <= 10.53
# |   |   |   |   |   |   |   |--- practical_salinity <= 33.95
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.94
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.94
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- practical_salinity >  33.95
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- sea_surface_temperature >  10.53
# |   |   |   |   |   |   |   |--- practical_salinity <= 33.97
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.95
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.95
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- practical_salinity >  33.97
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- seawater_temperature >  8.00
# |   |   |   |   |   |   |--- practical_salinity <= 33.93
# |   |   |   |   |   |   |   |--- practical_salinity <= 33.88
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 10.56
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  10.56
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- practical_salinity >  33.88
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 8.18
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  8.18
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- practical_salinity >  33.93
# |   |   |   |   |   |   |   |--- practical_salinity <= 33.94
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- practical_salinity >  33.94
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- sea_surface_temperature >  10.61
# |   |   |   |   |   |--- sea_surface_temperature <= 10.75
# |   |   |   |   |   |   |--- practical_salinity <= 33.90
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 10.71
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.86
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.86
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  10.71
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.83
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.83
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- practical_salinity >  33.90
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 10.70
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.96
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.96
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  10.70
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 8.11
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  8.11
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- sea_surface_temperature >  10.75
# |   |   |   |   |   |   |--- seawater_temperature <= 8.39
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.68
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.68
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.91
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.91
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- seawater_temperature >  8.39
# |   |   |   |   |   |   |   |--- practical_salinity <= 33.84
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- practical_salinity >  33.84
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- sea_surface_temperature >  10.83
# |   |   |   |--- seawater_temperature <= 7.79
# |   |   |   |   |--- sea_surface_temperature <= 10.93
# |   |   |   |   |   |--- practical_salinity <= 33.95
# |   |   |   |   |   |   |--- practical_salinity <= 33.93
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- practical_salinity >  33.93
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.71
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 10.90
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  10.90
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.71
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- practical_salinity >  33.95
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- sea_surface_temperature >  10.93
# |   |   |   |   |   |--- sea_surface_temperature <= 10.96
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- sea_surface_temperature >  10.96
# |   |   |   |   |   |   |--- practical_salinity <= 33.95
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- practical_salinity >  33.95
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- seawater_temperature >  7.79
# |   |   |   |   |--- practical_salinity <= 33.93
# |   |   |   |   |   |--- practical_salinity <= 33.91
# |   |   |   |   |   |   |--- seawater_temperature <= 7.94
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- seawater_temperature >  7.94
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 10.86
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  10.86
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 10.89
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  10.89
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- practical_salinity >  33.91
# |   |   |   |   |   |   |--- sea_surface_temperature <= 10.86
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sea_surface_temperature >  10.86
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 10.87
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  10.87
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 10.95
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  10.95
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- practical_salinity >  33.93
# |   |   |   |   |   |--- seawater_temperature <= 7.88
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- seawater_temperature >  7.88
# |   |   |   |   |   |   |--- class: 1.0
# |   |--- seawater_temperature >  8.79
# |   |   |--- sea_surface_temperature <= 10.58
# |   |   |   |--- practical_salinity <= 33.78
# |   |   |   |   |--- seawater_temperature <= 8.93
# |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- seawater_temperature >  8.93
# |   |   |   |   |   |--- practical_salinity <= 33.78
# |   |   |   |   |   |   |--- practical_salinity <= 33.77
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- practical_salinity >  33.77
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- practical_salinity >  33.78
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- practical_salinity >  33.78
# |   |   |   |   |--- sea_surface_temperature <= 10.55
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- sea_surface_temperature >  10.55
# |   |   |   |   |   |--- class: 1.0
# |   |   |--- sea_surface_temperature >  10.58
# |   |   |   |--- sea_surface_temperature <= 10.66
# |   |   |   |   |--- practical_salinity <= 33.78
# |   |   |   |   |   |--- seawater_temperature <= 9.01
# |   |   |   |   |   |   |--- sea_surface_temperature <= 10.59
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sea_surface_temperature >  10.59
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- seawater_temperature >  9.01
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- practical_salinity >  33.78
# |   |   |   |   |   |--- practical_salinity <= 33.81
# |   |   |   |   |   |   |--- sea_surface_temperature <= 10.58
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sea_surface_temperature >  10.58
# |   |   |   |   |   |   |   |--- seawater_temperature <= 8.82
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  8.82
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 8.89
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  8.89
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- practical_salinity >  33.81
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- sea_surface_temperature >  10.66
# |   |   |   |   |--- seawater_temperature <= 8.87
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- seawater_temperature >  8.87
# |   |   |   |   |   |--- class: 1.0
# |--- sea_surface_temperature >  11.01
# |   |--- sea_surface_temperature <= 13.51
# |   |   |--- practical_salinity <= 33.98
# |   |   |   |--- sea_surface_temperature <= 11.28
# |   |   |   |   |--- seawater_temperature <= 8.06
# |   |   |   |   |   |--- sea_surface_temperature <= 11.02
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- sea_surface_temperature >  11.02
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- seawater_temperature >  8.06
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- sea_surface_temperature >  11.28
# |   |   |   |   |--- sea_surface_temperature <= 11.78
# |   |   |   |   |   |--- seawater_temperature <= 7.53
# |   |   |   |   |   |   |--- seawater_temperature <= 7.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- seawater_temperature >  7.50
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- seawater_temperature >  7.53
# |   |   |   |   |   |   |--- sea_surface_temperature <= 11.30
# |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sea_surface_temperature >  11.30
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.96
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 11.69
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  11.69
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.96
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |--- sea_surface_temperature >  11.78
# |   |   |   |   |   |--- sea_surface_temperature <= 13.03
# |   |   |   |   |   |   |--- sea_surface_temperature <= 12.07
# |   |   |   |   |   |   |   |--- practical_salinity <= 33.96
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 7.49
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  7.49
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- practical_salinity >  33.96
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 7.06
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  7.06
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- sea_surface_temperature >  12.07
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 12.50
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 7.89
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  7.89
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  12.50
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 12.54
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  12.54
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- sea_surface_temperature >  13.03
# |   |   |   |   |   |   |--- sea_surface_temperature <= 13.21
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.67
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 13.07
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  13.07
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.67
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sea_surface_temperature >  13.21
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.49
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 13.33
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  13.33
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.49
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 7.55
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  7.55
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- practical_salinity >  33.98
# |   |   |   |--- practical_salinity <= 33.99
# |   |   |   |   |--- sea_surface_temperature <= 12.84
# |   |   |   |   |   |--- practical_salinity <= 33.98
# |   |   |   |   |   |   |--- practical_salinity <= 33.98
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- practical_salinity >  33.98
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 12.49
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  12.49
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- practical_salinity >  33.98
# |   |   |   |   |   |   |--- seawater_temperature <= 6.92
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- seawater_temperature >  6.92
# |   |   |   |   |   |   |   |--- practical_salinity <= 33.98
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.98
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.98
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- practical_salinity >  33.98
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- sea_surface_temperature >  12.84
# |   |   |   |   |   |--- sea_surface_temperature <= 12.86
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- sea_surface_temperature >  12.86
# |   |   |   |   |   |   |--- seawater_temperature <= 7.34
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.32
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.99
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.99
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.32
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- seawater_temperature >  7.34
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- practical_salinity >  33.99
# |   |   |   |   |--- seawater_temperature <= 6.87
# |   |   |   |   |   |--- seawater_temperature <= 6.84
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- seawater_temperature >  6.84
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- seawater_temperature >  6.87
# |   |   |   |   |   |--- class: 1.0
# |   |--- sea_surface_temperature >  13.51
# |   |   |--- seawater_temperature <= 7.75
# |   |   |   |--- practical_salinity <= 33.97
# |   |   |   |   |--- sea_surface_temperature <= 14.28
# |   |   |   |   |   |--- sea_surface_temperature <= 13.90
# |   |   |   |   |   |   |--- practical_salinity <= 33.96
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 13.77
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 13.53
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  13.53
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  13.77
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.95
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.95
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- practical_salinity >  33.96
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.25
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.25
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 7.37
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  7.37
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- sea_surface_temperature >  13.90
# |   |   |   |   |   |   |--- practical_salinity <= 33.96
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.68
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.95
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.95
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.68
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- practical_salinity >  33.96
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.27
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.97
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.97
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.27
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 14.18
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  14.18
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- sea_surface_temperature >  14.28
# |   |   |   |   |   |--- practical_salinity <= 33.94
# |   |   |   |   |   |   |--- sea_surface_temperature <= 14.86
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 14.36
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  14.36
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.94
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.94
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- sea_surface_temperature >  14.86
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- practical_salinity >  33.94
# |   |   |   |   |   |   |--- seawater_temperature <= 7.56
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 15.87
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.95
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.95
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  15.87
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 7.36
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  7.36
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- seawater_temperature >  7.56
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.74
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.96
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.96
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.74
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |--- practical_salinity >  33.97
# |   |   |   |   |--- sea_surface_temperature <= 13.87
# |   |   |   |   |   |--- practical_salinity <= 33.99
# |   |   |   |   |   |   |--- practical_salinity <= 33.98
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.29
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 13.66
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  13.66
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.29
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.97
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.97
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |--- practical_salinity >  33.98
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.21
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.98
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.98
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.21
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.98
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.98
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- practical_salinity >  33.99
# |   |   |   |   |   |   |--- practical_salinity <= 33.99
# |   |   |   |   |   |   |   |--- practical_salinity <= 33.99
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- practical_salinity >  33.99
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- practical_salinity >  33.99
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 13.78
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  13.78
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- sea_surface_temperature >  13.87
# |   |   |   |   |   |--- sea_surface_temperature <= 14.65
# |   |   |   |   |   |   |--- sea_surface_temperature <= 14.38
# |   |   |   |   |   |   |   |--- seawater_temperature <= 7.33
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.99
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.99
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- seawater_temperature >  7.33
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 7.34
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  7.34
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- sea_surface_temperature >  14.38
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 14.43
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 7.24
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  7.24
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  14.43
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.99
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.99
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- sea_surface_temperature >  14.65
# |   |   |   |   |   |   |--- seawater_temperature <= 7.22
# |   |   |   |   |   |   |   |--- practical_salinity <= 33.99
# |   |   |   |   |   |   |   |   |--- practical_salinity <= 33.98
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- practical_salinity >  33.98
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- practical_salinity >  33.99
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 15.28
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  15.28
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- seawater_temperature >  7.22
# |   |   |   |   |   |   |   |--- practical_salinity <= 33.99
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 7.41
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  7.41
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |--- practical_salinity >  33.99
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |--- seawater_temperature >  7.75
# |   |   |   |--- sea_surface_temperature <= 15.57
# |   |   |   |   |--- practical_salinity <= 33.97
# |   |   |   |   |   |--- sea_surface_temperature <= 14.38
# |   |   |   |   |   |   |--- seawater_temperature <= 7.79
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- seawater_temperature >  7.79
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- sea_surface_temperature >  14.38
# |   |   |   |   |   |   |--- seawater_temperature <= 7.98
# |   |   |   |   |   |   |   |--- practical_salinity <= 33.94
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 7.77
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  7.77
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- practical_salinity >  33.94
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 7.88
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  7.88
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- seawater_temperature >  7.98
# |   |   |   |   |   |   |   |--- practical_salinity <= 33.95
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- practical_salinity >  33.95
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature <= 15.12
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- sea_surface_temperature >  15.12
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- practical_salinity >  33.97
# |   |   |   |   |   |--- sea_surface_temperature <= 13.91
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- sea_surface_temperature >  13.91
# |   |   |   |   |   |   |--- sea_surface_temperature <= 14.55
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 14.53
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 7.87
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  7.87
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  14.53
# |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- sea_surface_temperature >  14.55
# |   |   |   |   |   |   |   |--- sea_surface_temperature <= 15.46
# |   |   |   |   |   |   |   |   |--- seawater_temperature <= 7.82
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |--- seawater_temperature >  7.82
# |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- sea_surface_temperature >  15.46
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |--- sea_surface_temperature >  15.57
# |   |   |   |   |--- sea_surface_temperature <= 15.81
# |   |   |   |   |   |--- seawater_temperature <= 7.94
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- seawater_temperature >  7.94
# |   |   |   |   |   |   |--- practical_salinity <= 33.95
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |--- practical_salinity >  33.95
# |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- sea_surface_temperature >  15.81
# |   |   |   |   |   |--- class: 1.0
# c:\users\derya\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass feature_names=['practical_salinity', 'seawater_temperature', 'sea_surface_temperature'] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
print(classification_report(y_test, gs_dt.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.77      0.74      1685
#          1.0       0.85      0.81      0.83      2744
#
#     accuracy                           0.79      4429
#    macro avg       0.78      0.79      0.78      4429
# weighted avg       0.80      0.79      0.80      4429

# %%
# ROC curve
fig, ax = plt.subplots(figsize=(8,8))

plot_roc_curve(gs_dt, X_test, y_test, ax=ax, name='Decision Tree')
plot_roc_curve(gs_lr, X_test, y_test, ax=ax, name='Logistic Regression')

# add worst case scenario line
plt.plot([0,1],[0,1], label='baseline', linestyle='--')

# add a legend
plt.legend();
# want AUC (area under curve) to be as close to 1 as possible

# %% [markdown]
# Interpretation goes here

# %% [markdown]
# #### Explore misclassified data

# %%
# Get indices of misclassified data
misclass_ind_dt = np.where(y_test != gs_dt_test_preds)
# misclass_ind_dt

# %%
X_test_times = df_resampled.iloc[X_test.index]['time']

# %%
X_test_times.iloc[misclass_ind_dt]
# Out:
# 7832    2017-04-22 22:00:00
# 1022    2017-01-16 11:00:00
# 546     2017-01-08 14:00:00
# 308     2017-01-05 06:40:00
# 5441    2017-03-20 17:00:00
#                 ...
# 2519    2017-02-06 19:00:00
# 5282    2017-03-18 12:00:00
# 9663    2017-05-19 14:20:00
# 17408   2017-09-11 18:00:00
# 7074    2017-04-12 09:20:00
# Name: time, Length: 912, dtype: datetime64[ns]

# %%
pd.DataFrame(X_test_times.iloc[misclass_ind_dt]).reset_index(drop=True)
# Out:
#                    time
# 0   2017-04-22 22:00:00
# 1   2017-01-16 11:00:00
# 2   2017-01-08 14:00:00
# 3   2017-01-05 06:40:00
# 4   2017-03-20 17:00:00
# ..                  ...
# 907 2017-02-06 19:00:00
# 908 2017-03-18 12:00:00
# 909 2017-05-19 14:20:00
# 910 2017-09-11 18:00:00
# 911 2017-04-12 09:20:00
#
# [912 rows x 1 columns]

# %%
frames_dt = [pd.DataFrame(X_test_times.iloc[misclass_ind_dt]), X_test.iloc[misclass_ind_dt], pd.DataFrame(y_test.iloc[misclass_ind_dt])]
misclass_df_dt = pd.concat(frames_dt, axis=1)

# %%
misclass_df_dt
# Out:
#                      time  practical_salinity  seawater_temperature  \
# 7832  2017-04-22 22:00:00           33.872223              8.268149
# 1022  2017-01-16 11:00:00           33.895588              8.239252
# 546   2017-01-08 14:00:00           33.924423              7.714611
# 308   2017-01-05 06:40:00           33.909872              7.833028
# 5441  2017-03-20 17:00:00           33.947078              7.776514
# ...                   ...                 ...                   ...
# 2519  2017-02-06 19:00:00           33.826399              8.517313
# 5282  2017-03-18 12:00:00           33.944735              7.652431
# 9663  2017-05-19 14:20:00           33.976587              7.240744
# 17408 2017-09-11 18:00:00           33.938600              7.971239
# 7074  2017-04-12 09:20:00           33.921680              7.779041
#
#        sea_surface_temperature  upwelling
# 7832                 10.734294        1.0
# 1022                 10.237200        1.0
# 546                  10.868400        0.0
# 308                  10.858200        1.0
# 5441                 10.384850        1.0
# ...                        ...        ...
# 2519                 10.433500        1.0
# 5282                 10.513300        1.0
# 9663                 12.525300        0.0
# 17408                14.612300        1.0
# 7074                 10.378147        1.0
#
# [912 rows x 5 columns]

# %%
sns.pairplot(misclass_df_dt, corner=True, hue='upwelling');

# %%
df_resampled['CUTI'] = df['CUTI']

df['CUTI']
# Out:
# 0         1.731
# 1         1.731
# 2         1.731
# 3         1.731
# 4         1.731
#           ...
# 329194   -0.194
# 329195   -0.194
# 329196   -0.194
# 329197   -0.194
# 329198   -0.194
# Name: CUTI, Length: 329199, dtype: float64

# %%
sns.set_style('whitegrid')

# %%
fig, (ax2, ax1) = plt.subplots(2,1, sharex=True, figsize = (24, 12)) 
ax1.scatter(x=df_resampled['time'], y=df_resampled['seawater_temperature'], c='g', s=1, label='Data')
ax1.set_ylabel('Seawater Temperature at 200 meters', size=24)
ax1.set_title('Misclassified Platform Data', size=24)

ax1.scatter(x=misclass_df_lr['time'], y=misclass_df_lr['seawater_temperature'], c='r', s=1, label='Log Reg Misclassified')
ax1.scatter(x=misclass_df_dt['time'], y=misclass_df_dt['seawater_temperature'], c='b', s=1, label='Decision Tree Misclassified')

ax2.scatter(x=df_resampled['time'], y=df_resampled['sea_surface_temperature'], c='g', s=1, label='Data')
ax2.set_xlabel('Time', size=24)
ax2.set_ylabel('Sea Surface Temperature', size=24)
ax2.set_title('Resampled METBK Data', size=24)

ax2.scatter(x=misclass_df_lr['time'], y=misclass_df_lr['sea_surface_temperature'], c='r', s=1, label='Log Reg Misclassified')
ax2.scatter(x=misclass_df_dt['time'], y=misclass_df_dt['sea_surface_temperature'], c='b', s=1, label='Decision Tree Misclassified')

ax2.legend(fontsize=16, scatterpoints=40)
ax1.legend(fontsize=16, scatterpoints=40)
plt.xticks(rotation=35);
plt.tight_layout()
plt.savefig('../figures/misclassified_data.png')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,8))

corr = misclass_df_dt.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(misclass_df_dt.corr(), annot=True, vmin=-1, vmax=1, mask=mask, ax=ax1)

corr = df_resampled.drop(columns='CUTI').corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(df_resampled.drop(columns='CUTI').corr(), annot=True, vmin=-1, vmax=1, mask=mask, ax=ax2);
